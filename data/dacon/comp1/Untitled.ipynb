# %%
import pandas as pd
import numpy as np
import missingno as msno

# %%
train = pd.read_csv('train.csv', header = 0, index_col = 0)
test = pd.read_csv('test.csv', header = 0, index_col = 0)
submit = pd.read_csv('sample_submission.csv', header = 0, index_col = 0)

print(train.shape)
print(test.shape)
print(submit.shape)
# Out:
# (10000, 75)
# (10000, 71)
# (10000, 4)

# %%
msno.matrix(train)

# %%
msno.matrix(test)

# %%
train.isnull().sum()[train.isnull().sum().values > 0]
# Out:
# 650_dst    1948
# 660_dst    1988
# 670_dst    1931
# 680_dst    1975
# 690_dst    2003
# 700_dst    1966
# 710_dst    1946
# 720_dst    2046
# 730_dst    2006
# 740_dst    1993
# 750_dst    2071
# 760_dst    2050
# 770_dst    1994
# 780_dst    1945
# 790_dst    2059
# 800_dst    2026
# 810_dst    1990
# 820_dst    2091
# 830_dst    1965
# 840_dst    2045
# 850_dst    2014
# 860_dst    2010
# 870_dst    2020
# 880_dst    1968
# 890_dst    2059
# 900_dst    1999
# 910_dst    2030
# 920_dst    2038
# 930_dst    1978
# 940_dst    2018
# 950_dst    2013
# 960_dst    2008
# 970_dst    2069
# 980_dst    1919
# 990_dst    1987
# dtype: int64

# %%
test.isnull().sum()[test.isnull().sum().values > 0]
# Out:
# 650_dst    2026
# 660_dst    1960
# 670_dst    2015
# 680_dst    2006
# 690_dst    1985
# 700_dst    1948
# 710_dst    2043
# 720_dst    2014
# 730_dst    2038
# 740_dst    1999
# 750_dst    1965
# 760_dst    2000
# 770_dst    1956
# 780_dst    2020
# 790_dst    2030
# 800_dst    1961
# 810_dst    2034
# 820_dst    2042
# 830_dst    2058
# 840_dst    1947
# 850_dst    2005
# 860_dst    2008
# 870_dst    2063
# 880_dst    2080
# 890_dst    1996
# 900_dst    1976
# 910_dst    1919
# 920_dst    1981
# 930_dst    2000
# 940_dst    1999
# 950_dst    1949
# 960_dst    2020
# 970_dst    1976
# 980_dst    2011
# 990_dst    1970
# dtype: int64
